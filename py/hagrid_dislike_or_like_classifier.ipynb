# %% [markdown]
# ### Import TensorFlow

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import os
import cv2 as cv

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !unzip '/content/drive/MyDrive/hagrid/newdislike.zip'
# Out:
# Archive:  /content/drive/MyDrive/hagrid/newdislike.zip
#    creating: newdislike/
#    creating: newdislike/test_images_dislike/
#   inflating: newdislike/test_images_dislike/00481821-8795-4011-bc0a-67f99fa53cac.jpg
#   inflating: newdislike/test_images_dislike/00713c1a-007e-4651-bef5-09c4019f19c6.jpg
#   inflating: newdislike/test_images_dislike/012210d4-d9d4-423b-bb5a-d014c8e34832.jpg
#   inflating: newdislike/test_images_dislike/01883f07-2dc8-4e88-b2da-01e7149b6029.jpg
#   inflating: newdislike/test_images_dislike/02015171-9f41-4eee-8956-c3e198d23de8.jpg
#   inflating: newdislike/test_images_dislike/02121efb-618f-4a71-9549-0f33b89f08b3.jpg
#   inflating: newdislike/test_images_dislike/02613d4b-1fad-4f32-818a-aaccc0d39f7a.jpg
#   inflating: newdislike/test_images_dislike/02638b22-b4a8-44d3-b726-ad9858d1f1f5.jpg
#   inflating: newdislike/test_images_dislike/02859656-e7e2-4e37-8d43-fa4eb2795f84.jpg
#   inflating: newdislike/test_images_dislike/02887c7f-4bac-411b-aeae-172b2e3d01ef.jpg
#   inflating: newdislike/test_images_dislike/03118bdc-9b5d-4f0f-910a-43755d3e862a.jpg
#   inflating: newdislike/test_images_dislike/03128978-c17d-4af5-a9fd-c230ba41e608.jpg
#   inflating: newdislike/test_images_dislike/03725111-5f59-4e87-854d-ba14b01c8606.jpg
#   inflating: newdislike/test_images_dislike/04225c04-1b83-4d80-ac3b-74b765c43d3e.jpg
#   inflating: newdislike/test_images_dislike/049130ea-36c7-460e-84cd-811fa0da431e.jpg
#   inflating: newdislike/test_images_dislike/05037a97-c299-434a-b31a-06ca099ac1f7.jpg
#   inflating: newdislike/test_images_dislike/05386ed0-2716-4ee7-8231-b6470bf4de3b.jpg
#   inflating: newdislike/test_images_dislike/05652b5e-a119-484d-8c94-d9fdfaccd9ba.jpg
#   inflating: newdislike/test_images_dislike/05703d63-4bd3-49b3-a236-e06d7dde5e58.jpg
#   inflating: newdislike/test_images_dislike/0591321c-ff2d-480f-bb0d-0c9946a8faca.jpg
#   inflating: newdislike/test_images_dislike/062704b2-58a6-42d6-866c-97a5564732f0.jpg
#   inflating: newdislike/test_images_dislike/0653fa7b-f5c1-4b1e-a3b9-be64363c2d69.jpg
#   inflating: newdislike/test_images_dislike/06629b4e-8975-44a9-9be2-67e48c8cc626.jpg
#   inflating: newdislike/test_images_dislike/066680a3-ffca-490e-943c-7938580b05f2.jpg
#   inflating: newdislike/test_images_dislike/06999615-2e93-4f3a-ab24-4538454b597d.jpg
#    creating: newdislike/test_images_like/
#   inflating: newdislike/test_images_like/002f1d76-250f-4322-b1c3-4dd4906780d4.jpg
#   inflating: newdislike/test_images_like/004ae8d7-e079-4665-a5cf-0d9b3fbc9398.jpg
#   inflating: newdislike/test_images_like/00b0135c-b2ed-439a-9bc1-8db448a0c451.jpg
#   inflating: newdislike/test_images_like/00bc44f3-0284-4a6a-892f-2131f68faf3d.jpg
#   inflating: newdislike/train_images_dislike/06b0fd08-aedc-4625-9787-d9f5129be574.jpg
#   inflating: newdislike/train_images_dislike/06bb328f-e737-4785-b9a7-de19d827d094.jpg
#   inflating: newdislike/train_images_dislike/06c26e1e-4adb-41e8-a472-d53626255b1c.jpg
#   inflating: newdislike/train_images_dislike/06ca0e75-b6b4-4b97-9afe-a727b0143ea4.jpg
#    creating: newdislike/train_images_like/
#   inflating: newdislike/train_images_like/.DS_Store
#    creating: newdislike/train_images_like/.ipynb_checkpoints/
#   inflating: newdislike/train_images_like/.ipynb_checkpoints/000484ab-5fd0-49b8-9253-23a22b71d7b1-checkpoint.jpg
#   inflating: newdislike/train_images_like/000484ab-5fd0-49b8-9253-23a22b71d7b1.jpg
#   inflating: newdislike/train_images_like/005762c1-ddc8-4ea3-becd-05f3ec326b03.jpg
#   inflating: newdislike/train_images_like/007e3be7-4095-469b-81aa-427c13454d77.jpg
#   inflating: newdislike/train_images_like/0100d24f-7881-465b-aed2-6a8d93ae2416.jpg
#   inflating: newdislike/train_images_like/01083636-1053-4abf-8b3a-f6f38b5491ce.jpg
#   inflating: newdislike/train_images_like/012d89fa-33f7-4922-932b-6971ce8a7a96.jpg
#   inflating: newdislike/train_images_like/0131e46b-a984-45d6-9e06-e750c58ad7fa.jpg
#   inflating: newdislike/train_images_like/01628eb2-125b-4a0d-958d-792d4ad61c5b.jpg
#   inflating: newdislike/train_images_like/01819d06-7d2d-4b03-b8d6-f4cba19f99e3.jpg
#   inflating: newdislike/train_images_like/020cd45b-a632-4bd1-b769-c66c8806fc00.jpg
#   inflating: newdislike/train_images_like/02115e99-917a-4784-80a4-b0ae81f3f725.jpg
#   inflating: newdislike/train_images_like/0219dd8f-3c30-4afe-8397-8a53090bfb69.jpg
#   inflating: newdislike/train_images_like/023bff3c-b953-4b7e-adc8-2dd8adf26a70.jpg
#   inflating: newdislike/train_images_like/0266d308-b686-44d2-9633-3d7433b8a536.jpg
#   inflating: newdislike/train_images_like/026e78fd-899b-4bf2-8d8c-aa020e5f40e9.jpg
#   inflating: newdislike/train_images_like/029ad35c-610b-4389-8a5a-f5b7f676d19b.jpg
#   inflating: newdislike/train_images_like/031a643e-ee00-4ecf-bada-daca0aa5c0c7.jpg
#   inflating: newdislike/train_images_like/0337edd6-1cb2-4093-a290-dc5f6f8ef2bd.jpg
#   inflating: newdislike/train_images_like/035b7ce4-0521-4b5a-ae58-291b1e7c4644.jpg
#   inflating: newdislike/train_images_like/04042884-b6f2-489d-86f0-95753a605f91.jpg
#   inflating: newdislike/train_images_like/042c535a-45fe-4c81-be1e-71a0b4348554.jpg
#   inflating: newdislike/train_images_like/0435ef27-e7f2-40f3-abff-ccebf1b423f1.jpg
#   inflating: newdislike/train_images_like/04378653-b318-43e4-8934-c05b2dfdfab2.jpg
#   inflating: newdislike/train_images_like/0445d444-dff5-42db-a7ec-dcac25faabde.jpg
#   inflating: newdislike/train_images_like/04594c34-7c21-40e9-bdb9-932b5198bf8e.jpg
#   inflating: newdislike/train_images_like/0487d1d7-2dac-48b6-979e-656c9dcf13f5.jpg
#   inflating: newdislike/train_images_like/048cb375-6ed6-42ce-ad37-032bba2cc27e.jpg
#   inflating: newdislike/train_images_like/0493f82c-1578-4acc-ba3e-4884b7c9783c.jpg
#   inflating: newdislike/train_images_like/04d93bd3-5d74-4c10-b8b3-80885219077c.jpg
#   inflating: newdislike/train_images_like/04ed14a5-5518-4df2-bf19-524d265ad747.jpg
#   inflating: newdislike/train_images_like/04f67146-3c0b-4b4a-9fa1-13b0b9a1b234.jpg
#   inflating: newdislike/train_images_like/04f86251-9ed7-4161-8fce-dc8d5d68d897.jpg
#   inflating: newdislike/train_images_like/050e7192-2e54-4f66-91af-5a6ac7a31dea.jpg
#   inflating: newdislike/train_images_like/051a711c-2d60-4e08-b86e-a3c6a7fdc73e.jpg
#   inflating: newdislike/train_images_like/052b7fcf-84c6-4fb4-aaca-9bb1cbb27c73.jpg
#   inflating: newdislike/train_images_like/052f9ac6-c6f5-4674-98dc-b61897dbd1a1.jpg
#   inflating: newdislike/train_images_like/05423551-c73d-4e91-aa45-a6446da873f3.jpg
#   inflating: newdislike/train_images_like/0545a256-7a74-4653-935e-273fd4c1f89c.jpg
#   inflating: newdislike/train_images_like/054993e9-b994-4809-b6b5-d959243b29a8.jpg
#   inflating: newdislike/train_images_like/0565d072-43a3-4bd5-94a6-261967785dfa.jpg
#   inflating: newdislike/train_images_like/057ef8cc-dc91-4455-a267-0a39b71faf51.jpg
#   inflating: newdislike/train_images_like/0583a7e4-d4a3-4a5a-bdd2-66ae2170279c.jpg
#   inflating: newdislike/train_images_like/0583dd64-f274-4533-99b2-4c47bf562b30.jpg
#   inflating: newdislike/train_images_like/0593b9f4-74a6-494f-95c4-f186ef10da57.jpg
#   inflating: newdislike/train_images_like/05a03461-338f-4b4e-9b41-06e0dd052f6c.jpg
#   inflating: newdislike/train_images_like/05b2fd16-d43d-4e14-bfa6-cfb9d5706ef2.jpg
#   inflating: newdislike/train_images_like/05b40519-a5e1-47fb-b68b-2c45c19b7805.jpg
#   inflating: newdislike/train_images_like/05b7f77a-971c-451a-9af1-92947e6227c2.jpg
#   inflating: newdislike/train_images_like/05c5af2c-3035-47c1-bef9-7960e73f9fbb.jpg
#   inflating: newdislike/train_images_like/05c80991-7d6c-42cb-b8ba-528cd942ca23.jpg
#   inflating: newdislike/train_images_like/05e18863-138d-481c-9196-2806664dce12.jpg
#   inflating: newdislike/train_images_like/060e140b-97a3-4700-94d1-e95c1ef598fb.jpg
#   inflating: newdislike/train_images_like/06151a5f-c40b-4134-a081-420324c89942.jpg
#   inflating: newdislike/train_images_like/062ba42e-035a-4088-adbd-bee3a08da9cb.jpg
#   inflating: newdislike/train_images_like/0651e2dc-b593-4007-bc06-2b7db9da0b18.jpg
#   inflating: newdislike/train_images_like/069c5f2d-ef83-4339-955f-8c661ce48ea2.jpg
#   inflating: newdislike/train_images_like/069f9cca-dca1-4ee0-97cb-13d507b0b48a.jpg
#   inflating: newdislike/train_images_like/06b88a7f-fb2c-464c-8c20-7612cfeed344.jpg
#   inflating: newdislike/train_images_like/06bf18e1-3288-4647-9d3e-97f79d061392.jpg
#   inflating: newdislike/train_images_like/06c45baf-365e-49ec-afc5-33bbbdc67aba.jpg
#   inflating: newdislike/train_images_like/06d66a9d-bfbd-4a8a-a0ff-6c0f7e641118.jpg
#   inflating: newdislike/train_images_like/06f0d24b-5490-4bb4-9041-0e690acd3e90.jpg
#   inflating: newdislike/train_images_like/073503d5-918a-41f6-ae02-6a67e6c8de27.jpg
#   inflating: newdislike/train_images_like/073ed106-bc1b-446d-9223-379b4233b544.jpg
#   inflating: newdislike/train_images_like/07525e27-dfe9-4748-8431-06c73a7cfd03.jpg
#   inflating: newdislike/train_images_like/076e0e49-8129-49fb-86bd-2c260ddba632.jpg
#   inflating: newdislike/train_images_like/076fc491-c8ca-4612-a9e8-bb46f432bf3c.jpg
#   inflating: newdislike/train_images_like/0788f4c2-6e58-4f99-8228-8126aa124379.jpg
#   inflating: newdislike/train_images_like/07cbe4bd-e5eb-4e20-a3af-9cfb55a833ff.jpg
#   inflating: newdislike/train_images_like/07dfefcf-b667-497e-aac3-53a600dd7457.jpg
#   inflating: newdislike/train_images_like/07fdd88e-180a-4311-aa44-52208a618918.jpg
#   inflating: newdislike/train_images_like/08102c7e-abd4-4514-a73c-029fc2ad5415.jpg
#   inflating: newdislike/train_images_like/0824f2f9-c590-4b73-b9eb-d6d00fca791a.jpg
#   inflating: newdislike/train_images_like/084ec62d-b27e-4bb7-b836-975edb892a32.jpg
#   inflating: newdislike/train_images_like/085abd8c-bb77-49f0-a2f0-30164ae67441.jpg

# %% [markdown]
# For our project, we decided to make a model that can classify whether an image has a thumbs up or thumbs down. The dataset has 200 images in the 2 classes, like and dislike, with 100 images in each class. Both 100 images are split into 75 training images and 25 test images.

# %%
from tqdm import tqdm
import imageio as iio

# %%
# TEST
# load the image and convert into
# numpy array
d1 = 'newdislike/train_images_dislike/'
d2 = 'newdislike/test_images_dislike/'
l1 = 'newdislike/train_images_like/'
l2 = 'newdislike/test_images_like/'

resized_d1 = []
resized_d2 = []
resized_l1 = []
resized_l2 = []

size = (32, 32)

# train_dislike
for filename in tqdm(os.listdir(d1)):
    if filename.endswith("jpg"): 
        img = iio.imread(d1 + filename)
        res = cv.resize(img, size)
        res2 = np.asarray(res)
        resized_d1.append(res)

# test_dislike
for filename in tqdm(os.listdir(d2)):
    if filename.endswith("jpg"): 
        img = iio.imread(d2 + filename)
        res = cv.resize(img, size)
        res2 = np.asarray(res)
        resized_d2.append(res)

# train_like
for filename in tqdm(os.listdir(l1)):
    if filename.endswith("jpg"): 
        img = iio.imread(l1 + filename)
        res = cv.resize(img, size)
        res2 = np.asarray(res)
        resized_l1.append(res)

# test_like
for filename in tqdm(os.listdir(l2)):
    if filename.endswith("jpg"): 
        img = iio.imread(l2 + filename)
        res = cv.resize(img, size)
        res2 = np.asarray(res)
        resized_l2.append(res2)
# Out:
# 100%|██████████| 75/75 [00:00<00:00, 276.98it/s]
# 100%|██████████| 25/25 [00:00<00:00, 308.55it/s]
# 100%|██████████| 77/77 [00:00<00:00, 435.02it/s]
# 100%|██████████| 25/25 [00:00<00:00, 443.62it/s]

# %%
resized_d1.extend(resized_l1)
train1 = resized_d1

# %%
resized_d2.extend(resized_l2)
test1 = resized_d2

# %%
label_train = []
label_test = []

for i in range(75):
  label_train.append(0)

for i in range(75):
  label_train.append(1)

for i in range(25):
  label_test.append(0)

for i in range(25):
  label_test.append(1)

# %%
label_train = np.asarray(label_train, dtype='uint8')
label_test = np.asarray(label_test, dtype='uint8')

# %%
# (train_images, train_labels), (test_images, test_labels) = (train1, label_train), (test1, label_test)

train_images = train1
train_labels = label_train
test_images = test1
test_labels = label_test

# Normalize pixel values to be between 0 and 1
train_images, test_images = (np.asarray(train_images)) / 255.0, (np.asarray(test_images)) / 255.0

# %% [markdown]
# ### Verify the data
#
# To verify that the dataset looks correct, let's plot the first 25 images from the training set and display the class name below each image:

# %%
from random import seed
from random import randint

class_names = ['dislike', 'like']

plt.figure(figsize=(10,10))
for i in range(25):
    num = randint(0, 149)
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[num])
    # The CIFAR labels happen to be arrays, 
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[num]])
plt.show()

# %% [markdown]
# ### Create the convolutional base

# %% [markdown]
# The 6 lines of code below define the convolutional base using a common pattern: a stack of [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) and [MaxPooling2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D) layers.
#
# As input, a CNN takes tensors of shape (image_height, image_width, color_channels), ignoring the batch size. If you are new to these dimensions, color_channels refers to (R,G,B). In this example, you will configure your CNN to process inputs of shape (32, 32, 3), which is the format of our images. You can do this by passing the argument `input_shape` to your first layer.

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %% [markdown]
# Let's display the architecture of your model so far:

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
# =================================================================
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Above, you can see that the output of every Conv2D and MaxPooling2D layer is a 3D tensor of shape (height, width, channels). The width and height dimensions tend to shrink as you go deeper in the network. The number of output channels for each Conv2D layer is controlled by the first argument (e.g., 32 or 64). Typically,  as the width and height shrink, you can afford (computationally) to add more output channels in each Conv2D layer.

# %% [markdown]
# ### Add Dense layers on top
#
# To complete the model, you will feed the last output tensor from the convolutional base (of shape (4, 4, 64)) into one or more Dense layers to perform classification. Dense layers take vectors as input (which are 1D), while the current output is a 3D tensor. First, you will flatten (or unroll) the 3D output to 1D,  then add one or more Dense layers on top. CIFAR has 10 output classes, so you use a final Dense layer with 10 outputs.

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(2))

# %% [markdown]
# Here's the complete architecture of your model:

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# The network summary shows that (4, 4, 64) outputs were flattened into vectors of shape (1024) before going through two Dense layers.

# %% [markdown]
# ### Compile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=50, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 12s 140ms/step - loss: 0.7016 - accuracy: 0.5067 - val_loss: 0.6754 - val_accuracy: 0.5200
# Epoch 2/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6570 - accuracy: 0.6733 - val_loss: 0.6466 - val_accuracy: 0.7000
# Epoch 3/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.6042 - accuracy: 0.6867 - val_loss: 0.5454 - val_accuracy: 0.7800
# Epoch 4/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4867 - accuracy: 0.8200 - val_loss: 0.4470 - val_accuracy: 0.7800
# Epoch 5/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3980 - accuracy: 0.8600 - val_loss: 0.3603 - val_accuracy: 0.8200
# Epoch 6/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2913 - accuracy: 0.9000 - val_loss: 0.3063 - val_accuracy: 0.8800
# Epoch 7/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2143 - accuracy: 0.9267 - val_loss: 0.2651 - val_accuracy: 0.8600
# Epoch 8/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1820 - accuracy: 0.9400 - val_loss: 0.2439 - val_accuracy: 0.9400
# Epoch 9/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1847 - accuracy: 0.9267 - val_loss: 0.1785 - val_accuracy: 0.9600
# Epoch 10/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1163 - accuracy: 0.9467 - val_loss: 0.2063 - val_accuracy: 0.8800
# Epoch 11/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0944 - accuracy: 0.9667 - val_loss: 0.1414 - val_accuracy: 0.9600
# Epoch 12/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0814 - accuracy: 0.9733 - val_loss: 0.2546 - val_accuracy: 0.8600
# Epoch 13/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0655 - accuracy: 0.9800 - val_loss: 0.1279 - val_accuracy: 0.9600
# Epoch 14/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0639 - accuracy: 0.9800 - val_loss: 0.1982 - val_accuracy: 0.8800
# Epoch 15/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0611 - accuracy: 0.9867 - val_loss: 0.3657 - val_accuracy: 0.8400
# Epoch 16/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0630 - accuracy: 0.9867 - val_loss: 0.1273 - val_accuracy: 0.9600
# Epoch 17/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0506 - accuracy: 0.9867 - val_loss: 0.3638 - val_accuracy: 0.8600
# Epoch 18/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.1143 - val_accuracy: 0.9400
# Epoch 19/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0593 - accuracy: 0.9733 - val_loss: 0.3031 - val_accuracy: 0.8600
# Epoch 20/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0423 - accuracy: 0.9933 - val_loss: 0.2551 - val_accuracy: 0.8600
# Epoch 21/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.1104 - val_accuracy: 0.9400
# Epoch 22/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0239 - accuracy: 1.0000 - val_loss: 0.1667 - val_accuracy: 0.9200
# Epoch 23/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.2264 - val_accuracy: 0.9000
# Epoch 24/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9400
# Epoch 25/50
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.1992 - val_accuracy: 0.9400
# Epoch 26/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.1756 - val_accuracy: 0.9400
# Epoch 27/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9400
# Epoch 28/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.1769 - val_accuracy: 0.9400
# Epoch 29/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.1853 - val_accuracy: 0.9200
# Epoch 30/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.1399 - val_accuracy: 0.9400
# Epoch 31/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1775 - val_accuracy: 0.9400
# Epoch 32/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1942 - val_accuracy: 0.9200
# Epoch 33/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1708 - val_accuracy: 0.9400
# Epoch 34/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.9400
# Epoch 35/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2003 - val_accuracy: 0.9200
# Epoch 36/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9200
# Epoch 37/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1770 - val_accuracy: 0.9200
# Epoch 38/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9200
# Epoch 39/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1948 - val_accuracy: 0.9200
# Epoch 40/50
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1839 - val_accuracy: 0.9200
# Epoch 41/50
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9200
# Epoch 42/50
# 5/5 [==============================] - 0s 13ms/step - loss: 9.0315e-04 - accuracy: 1.0000 - val_loss: 0.1972 - val_accuracy: 0.9200
# Epoch 43/50
# 5/5 [==============================] - 0s 10ms/step - loss: 8.3376e-04 - accuracy: 1.0000 - val_loss: 0.2052 - val_accuracy: 0.9200
# Epoch 44/50
# 5/5 [==============================] - 0s 9ms/step - loss: 7.7413e-04 - accuracy: 1.0000 - val_loss: 0.2098 - val_accuracy: 0.9200
# Epoch 45/50
# 5/5 [==============================] - 0s 10ms/step - loss: 7.1864e-04 - accuracy: 1.0000 - val_loss: 0.2014 - val_accuracy: 0.9200
# Epoch 46/50
# 5/5 [==============================] - 0s 9ms/step - loss: 6.7179e-04 - accuracy: 1.0000 - val_loss: 0.2175 - val_accuracy: 0.9200
# Epoch 47/50
# 5/5 [==============================] - 0s 9ms/step - loss: 6.3347e-04 - accuracy: 1.0000 - val_loss: 0.2031 - val_accuracy: 0.9200
# Epoch 48/50
# 5/5 [==============================] - 0s 9ms/step - loss: 5.8141e-04 - accuracy: 1.0000 - val_loss: 0.2122 - val_accuracy: 0.9200
# Epoch 49/50
# 5/5 [==============================] - 0s 10ms/step - loss: 5.3769e-04 - accuracy: 1.0000 - val_loss: 0.2367 - val_accuracy: 0.9200
# Epoch 50/50
# 5/5 [==============================] - 0s 9ms/step - loss: 5.2300e-04 - accuracy: 1.0000 - val_loss: 0.2221 - val_accuracy: 0.9200

# %% [markdown]
# ### Evaluate the model

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 2/2 - 0s - loss: 0.2221 - accuracy: 0.9200 - 19ms/epoch - 9ms/step

# %%
print(test_acc)
# Out:
# 0.9200000166893005

# %% [markdown]
# ## Retrieve Trained Layers

# %% [markdown]
# Let us first take a look at the model by using *.get_weights* method.

# %%
len(model.get_weights())
# Out:
# 10

# %%
[model.get_weights()[i].shape for i in range(10)]
# Out:
# [(3, 3, 3, 32),
#  (32,),
#  (3, 3, 32, 64),
#  (64,),
#  (3, 3, 64, 64),
#  (64,),
#  (1024, 64),
#  (64,),
#  (64, 10),
#  (10,)]

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# !pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting visualkeras
#   Downloading visualkeras-0.0.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Collecting aggdraw>=1.3.11
#   Downloading aggdraw-1.3.15-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (989 kB)
#      |████████████████████████████████| 989 kB 5.1 MB/s
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.3.15 visualkeras-0.0.2

# %%
import visualkeras

# %%
visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=356x160 at 0x7F33B3651950>

# %%
model.inputs
# Out:
# [<KerasTensor: shape=(None, 32, 32, 3) dtype=float32 (created by layer 'conv2d_9_input')>]

# %%
model.output
# Out:
# <KerasTensor: shape=(None, 10) dtype=float32 (created by layer 'dense_3')>

# %%
model.get_layer('conv2d_12').output
# Out:
# <KerasTensor: shape=(None, 30, 30, 32) dtype=float32 (created by layer 'conv2d_12')>

# %%
tmp_engine = tf.keras.models.Model(
    inputs=model.inputs,
    outputs=model.get_layer('conv2d_12').output)

# %%
train_images.shape
# Out:
# (150, 32, 32, 3)

# %%
tmp_engine.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12_input (InputLayer  [(None, 32, 32, 3)]      0
#  )
#
#  conv2d_12 (Conv2D)          (None, 30, 30, 32)        896
#
# =================================================================
# Total params: 896
# Trainable params: 896
# Non-trainable params: 0
# _________________________________________________________________

# %%
tmp_conv2d_1_layer_for_this_sample = tmp_engine(train_images[0].reshape((1, 32, 32, 3)))
tmp_conv2d_1_layer_for_this_sample.shape
# Out:
# TensorShape([1, 30, 30, 32])

# %%
tmp_conv2d_1_layer_for_this_sample.shape[3]
# Out:
# 32

# %%
plt.imshow(tmp_conv2d_1_layer_for_this_sample[0,:,:,7])
plt.colorbar()

# %% [markdown]
# The original picture is printed as well.

# %%
plt.imshow(train_images[0])

# %%
plt.figure(figsize=(15,15))
for i in range(tmp_conv2d_1_layer_for_this_sample.shape[3]):
    plt.subplot(8, 8, i+1)
    plt.imshow(tmp_conv2d_1_layer_for_this_sample[0,:,:,i])

plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %% [markdown]
# Let's display the architecture of your model so far:

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 64)          36928
#
# =================================================================
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(16))
model.add(layers.Dense(8))
model.add(layers.Dense(4))
model.add(layers.Dense(2, activation='softmax'))

# %% [markdown]
# Here's the complete architecture of your model:

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 30, 30, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 64)          36928
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 44)                2860
#
#  dense_2 (Dense)             (None, 24)                1080
#
#  dense_3 (Dense)             (None, 18)                450
#
#  dense_4 (Dense)             (None, 14)                266
#
#  dense_5 (Dense)             (None, 7)                 105
#
#  dense_6 (Dense)             (None, 4)                 32
#
#  dense_7 (Dense)             (None, 2)                 10
#
#  flatten_1 (Flatten)         (None, 2)                 0
#
#  dense_8 (Dense)             (None, 64)                192
#
#  dense_9 (Dense)             (None, 44)                2860
#
#  dense_10 (Dense)            (None, 24)                1080
#
#  dense_11 (Dense)            (None, 18)                450
#
#  dense_12 (Dense)            (None, 14)                266
#
#  dense_13 (Dense)            (None, 9)                 135
#
#  dense_14 (Dense)            (None, 7)                 70
#
#  dense_15 (Dense)            (None, 4)                 32
#
#  dense_16 (Dense)            (None, 2)                 10
#
# =================================================================
# Total params: 131,818
# Trainable params: 131,818
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# The network summary shows that (4, 4, 64) outputs were flattened into vectors of shape (1024) before going through two Dense layers.

# %% [markdown]
# ### Compile and train the model

# %% [markdown]
# ### Evaluate the model

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 2/2 - 0s - loss: 0.4420 - accuracy: 0.9400 - 22ms/epoch - 11ms/step

# %% [markdown]
# ## Retrieve Trained Layers

# %% [markdown]
# Let us first take a look at the model by using *.get_weights* method.

# %%
len(model.get_weights())
# Out:
# 40

# %%
[model.get_weights()[i].shape for i in range(10)]
# Out:
# [(3, 3, 3, 32),
#  (32,),
#  (3, 3, 32, 64),
#  (64,),
#  (3, 3, 64, 64),
#  (64,),
#  (1024, 64),
#  (64,),
#  (64, 44),
#  (44,)]

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# !pip install visualkeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.7/dist-packages (0.0.2)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.21.6)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (7.1.2)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.7/dist-packages (from visualkeras) (1.3.15)

# %%
import visualkeras

# %%
visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=836x160 at 0x7F13A5D65BD0>
